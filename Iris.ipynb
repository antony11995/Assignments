# %%
#First thing that I did, was open iris.data as a plain text, added the name of columns and save as .csv

# I'm importing the libraries that I need to use
# %matplotlib inline
import pandas as pd
import numpy as np

#Reading the csv file and set up content inside variables
file1=pd.read_csv("iris.csv")

# %%
#Now, I want to know total columns, row, data type and size on disk:
file1.info()
#Using head() to check columns name and a preview of the first rows
file1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal-Length    150 non-null float64
# Sepal-width     150 non-null float64
# Petal-Length    150 non-null float64
# Petal-width     150 non-null float64
# Class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
#    Sepal-Length  Sepal-width  Petal-Length  Petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Checking nulls/NaN values
pd.isnull(file1).sum()
# Out:
# Sepal-Length    0
# Sepal-width     0
# Petal-Length    0
# Petal-width     0
# Class           0
# dtype: int64

# %%
#Checking the number of rows grouping by Class
file1.groupby(by="Class").count()
# Out:
#                  Sepal-Length  Sepal-width  Petal-Length  Petal-width
# Class
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
#creating a plot by column
file1.plot.hist()

# %%
# I have done a research on the internet about Iris plants that I want take a loo and 
# check the rows and count by following some of this proposals in the Decision tree for Iris Dataset to practice
#In this link:
#https://books.google.es/books?id=TmvWI-b77AIC&pg=PA141&lpg=PA141&dq=6.4,3.2,4.5,1.5,Iris-versicolor&source=bl&ots=qNQ39uR9yN&sig=ACfU3U2OvGx8j7mxXtFJDt9Mc9PI8h4jOg&hl=en&sa=X&ved=2ahUKEwiYn-nLwqzhAhVBSN8KHc_BDmMQ6AEwA3oECAkQAQ#v=onepage&q=6.4%2C3.2%2C4.5%2C1.5%2CIris-versicolor&f=false

file1[(file1['Petal-width'] <= 0.6)].count()
# Out:
# Sepal-Length    50
# Sepal-width     50
# Petal-Length    50
# Petal-width     50
# Class           50
# dtype: int64

# %%
file1[(file1['Petal-width'] <= 1.7)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
file1[(file1['Petal-width'] <= 1.7)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
file1[(file1['Petal-width'] <= 1.7)].count()
# Out:
# Sepal-Length    104
# Sepal-width     104
# Petal-Length    104
# Petal-width     104
# Class           104
# dtype: int64

# %%
file1[(file1['Petal-width'] > 1.7)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 102           7.1          3.0           5.9          2.1   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 104           6.5          3.0           5.8          2.2   Iris-virginica
# 105           7.6          3.0           6.6          2.1   Iris-virginica
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# 110           6.5          3.2           5.1          2.0   Iris-virginica
# ...

# %%
file1[(file1['Petal-width'] > 1.7)].count()
# Out:
# Sepal-Length    46
# Sepal-width     46
# Petal-Length    46
# Petal-width     46
# Class           46
# dtype: int64

# %%
file1[(file1['Petal-width'] <= 1.5)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
file1[(file1['Petal-width'] <= 1.5)].count()
# Out:
# Sepal-Length    98
# Sepal-width     98
# Petal-Length    98
# Petal-width     98
# Class           98
# dtype: int64

# %%
file1[(file1['Petal-width'] > 1.5)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 77            6.7          3.0           5.0          1.7  Iris-versicolor
# 83            6.0          2.7           5.1          1.6  Iris-versicolor
# 85            6.0          3.4           4.5          1.6  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 102           7.1          3.0           5.9          2.1   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 104           6.5          3.0           5.8          2.2   Iris-virginica
# 105           7.6          3.0           6.6          2.1   Iris-virginica
# ...

# %%
file1[(file1['Petal-width'] > 1.5)].count()
# Out:
# Sepal-Length    52
# Sepal-width     52
# Petal-Length    52
# Petal-width     52
# Class           52
# dtype: int64

# %%
file1[(file1['Petal-Length'] <= 4.9)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
file1[(file1['Petal-Length'] <= 4.9)].count()
# Out:
# Sepal-Length    104
# Sepal-width     104
# Petal-Length    104
# Petal-width     104
# Class           104
# dtype: int64

# %%
file1[(file1['Petal-Length'] > 4.9)]
# Out:
#      Sepal-Length  Sepal-width  Petal-Length  Petal-width            Class
# 77            6.7          3.0           5.0          1.7  Iris-versicolor
# 83            6.0          2.7           5.1          1.6  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 102           7.1          3.0           5.9          2.1   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 104           6.5          3.0           5.8          2.2   Iris-virginica
# 105           7.6          3.0           6.6          2.1   Iris-virginica
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# ...

# %%
file1[(file1['Petal-Length'] > 4.9)].count()
# Out:
# Sepal-Length    46
# Sepal-width     46
# Petal-Length    46
# Petal-width     46
# Class           46
# dtype: int64
